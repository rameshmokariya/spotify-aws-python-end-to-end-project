# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="910f3f6bd2dd4ee5b05a352ead10d53c",client_secret="7a677543b17d40c8af4be1a141d51347")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg"

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'album_name':album_name,
                     'album_release_date':album_release_date,
                     'album_total_tracks':album_total_tracks,
                     'album_url':album_url}
    album_list.append(album_element)

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],
                              'artist_name':artist['name'],
                              'external_url':artist['href']}
                #artist_dict['album_id'] = row['track']['album']['id']
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                      album_name album_release_date  \
# 0  0upenH0uUT36nBbVM5mQhW                  Jo Tum Mere Ho         2024-08-02
# 1  2P2orRpVU0F2Z1HGTi7AiS    Aaj Ki Raat (From "Stree 2")         2024-07-24
# 2  7tCxLHdbch1AEkuv2EbLQc       Aayi Nai (From "Stree 2")         2024-08-01
# 3  5KF4xCxDD8ip003hoatFT9                           GLORY         2024-08-26
# 4  3I3kZyHUtEA9Y59rJkxtk6  Sajni (From "Laapataa Ladies")         2024-02-12
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1                   1  https://open.spotify.com/album/2P2orRpVU0F2Z1H...
# 2                   1  https://open.spotify.com/album/7tCxLHdbch1AEku...
# 3                  18  https://open.spotify.com/album/5KF4xCxDD8ip003...
# 4                   1  https://open.spotify.com/album/3I3kZyHUtEA9Y59...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                      album_name album_release_date  \
# 0  0upenH0uUT36nBbVM5mQhW                  Jo Tum Mere Ho         2024-08-02
# 1  2P2orRpVU0F2Z1HGTi7AiS    Aaj Ki Raat (From "Stree 2")         2024-07-24
# 2  7tCxLHdbch1AEkuv2EbLQc       Aayi Nai (From "Stree 2")         2024-08-01
# 3  5KF4xCxDD8ip003hoatFT9                           GLORY         2024-08-26
# 4  3I3kZyHUtEA9Y59rJkxtk6  Sajni (From "Laapataa Ladies")         2024-02-12
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1                   1  https://open.spotify.com/album/2P2orRpVU0F2Z1H...
# 2                   1  https://open.spotify.com/album/7tCxLHdbch1AEku...
# 3                  18  https://open.spotify.com/album/5KF4xCxDD8ip003...
# 4                   1  https://open.spotify.com/album/3I3kZyHUtEA9Y59...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  4gdMJYnopf2nEUcanAwstx             Anuv Jain
# 1  1mBydYMVBECdDmMfE2sEUO          Sachin-Jigar
# 2  4ojkMVHjuDZgDXSJy5qs2h     Madhubanti Bagchi
# 3  0NErdIJtuKBjtxKmlqaWdj           Divya Kumar
# 4  2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4gdMJYnopf2...
# 1  https://api.spotify.com/v1/artists/1mBydYMVBEC...
# 2  https://api.spotify.com/v1/artists/4ojkMVHjuDZ...
# 3  https://api.spotify.com/v1/artists/0NErdIJtuKB...
# 4  https://api.spotify.com/v1/artists/2fMqTqiTxUD...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     114 non-null    object
#  1   artist_name   114 non-null    object
#  2   external_url  114 non-null    object
# dtypes: object(3)
# memory usage: 2.8+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  4gdMJYnopf2nEUcanAwstx             Anuv Jain
# 1  1mBydYMVBECdDmMfE2sEUO          Sachin-Jigar
# 2  4ojkMVHjuDZgDXSJy5qs2h     Madhubanti Bagchi
# 3  0NErdIJtuKBjtxKmlqaWdj           Divya Kumar
# 4  2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4gdMJYnopf2...
# 1  https://api.spotify.com/v1/artists/1mBydYMVBEC...
# 2  https://api.spotify.com/v1/artists/4ojkMVHjuDZ...
# 3  https://api.spotify.com/v1/artists/0NErdIJtuKB...
# 4  https://api.spotify.com/v1/artists/2fMqTqiTxUD...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                       song_name  duration_ms  \
# 0  0eCajpR75pDW0r64U6hP2x                  Jo Tum Mere Ho       251813
# 1  5AnWrUzsrFgBvhn6dUElnr    Aaj Ki Raat (From "Stree 2")       228620
# 2  1mQUEvGR7Sbt2OCz2gFrdx       Aayi Nai (From "Stree 2")       178780
# 3  78BWCd70D1X6LMkDZm1UoF                     Millionaire       199114
# 4  5zCnGtCl5Ac5zlFHXaZmhy  Sajni (From "Laapataa Ladies")       170044
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0eCajpR75pDW0r6...          80
# 1  https://open.spotify.com/track/5AnWrUzsrFgBvhn...          82
# 2  https://open.spotify.com/track/1mQUEvGR7Sbt2OC...          79
# 3  https://open.spotify.com/track/78BWCd70D1X6LMk...          80
# 4  https://open.spotify.com/track/5zCnGtCl5Ac5zlF...          82
#
#              song_added                album_id               artist_id
# 0  2024-09-21T13:22:54Z  0upenH0uUT36nBbVM5mQhW  4gdMJYnopf2nEUcanAwstx
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])
song_df.head()
# Out:
#                   song_id                       song_name  duration_ms  \
# 0  0eCajpR75pDW0r64U6hP2x                  Jo Tum Mere Ho       251813
# 1  5AnWrUzsrFgBvhn6dUElnr    Aaj Ki Raat (From "Stree 2")       228620
# 2  1mQUEvGR7Sbt2OCz2gFrdx       Aayi Nai (From "Stree 2")       178780
# 3  78BWCd70D1X6LMkDZm1UoF                     Millionaire       199114
# 4  5zCnGtCl5Ac5zlFHXaZmhy  Sajni (From "Laapataa Ladies")       170044
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0eCajpR75pDW0r6...          80
# 1  https://open.spotify.com/track/5AnWrUzsrFgBvhn...          82
# 2  https://open.spotify.com/track/1mQUEvGR7Sbt2OC...          79
# 3  https://open.spotify.com/track/78BWCd70D1X6LMk...          80
# 4  https://open.spotify.com/track/5zCnGtCl5Ac5zlF...          82
#
#              song_added                album_id               artist_id
# 0  2024-09-21T13:22:54Z  0upenH0uUT36nBbVM5mQhW  4gdMJYnopf2nEUcanAwstx
# ...
